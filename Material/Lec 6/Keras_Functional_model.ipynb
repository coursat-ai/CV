# %%
from keras import models
from keras import layers
from keras.utils import plot_model
 
inp = layers.Input(shape=(150,150,3))
 
# Branch 1
x = layers.Conv2D(32, (3,3))(inp)
x = layers.Conv2D(32, (3,3))(x)
out_1 = layers.Conv2D(32, (3,3))(x)
 
# Branch 2
x1 = layers.Conv2D(64, (3,3))(inp)
x1 = layers.Conv2D(32, (3,3))(x1)
out_2 = layers.Conv2D(32, (3,3))(x1)
 
#merged = layers.Concatenate([out_1, out_2])
 
# func
model = models.Model(inputs=inp, outputs=[out_1, out_2])

 
model.summary()
plot_model(model)
# Out:
# Using TensorFlow backend.
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 150, 150, 3)  0
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 148, 148, 32) 896         input_1[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 148, 148, 64) 1792        input_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 146, 146, 32) 9248        conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 146, 146, 32) 18464       conv2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 144, 144, 32) 9248        conv2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 144, 144, 32) 9248        conv2d_5[0][0]
# ==================================================================================================
# Total params: 48,896
# Trainable params: 48,896
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
from keras import models
from keras import layers
from keras.utils import plot_model

inp = layers.Input(shape=(5,))

# Branch 1
x = layers.Dense(100)(inp)
x = layers.Dense(100)(x)
out_1 = layers.Dense(100)(x)

# Branch 2
x1 = layers.Dense(200)(inp)
x1 = layers.Dense(200)(x1)
out_2 = layers.Dense(200)(x1)

#merged = layers.Concatenate([out_1, out_2])

# func
model = models.Model(inputs=inp, outputs=[out_1, out_2])

model.summary()
plot_model(model, show_shapes=True)
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_3 (InputLayer)            (None, 5)            0
# __________________________________________________________________________________________________
# dense_13 (Dense)                (None, 100)          600         input_3[0][0]
# __________________________________________________________________________________________________
# dense_16 (Dense)                (None, 200)          1200        input_3[0][0]
# __________________________________________________________________________________________________
# dense_14 (Dense)                (None, 100)          10100       dense_13[0][0]
# __________________________________________________________________________________________________
# dense_17 (Dense)                (None, 200)          40200       dense_16[0][0]
# __________________________________________________________________________________________________
# dense_15 (Dense)                (None, 100)          10100       dense_14[0][0]
# __________________________________________________________________________________________________
# dense_18 (Dense)                (None, 200)          40200       dense_17[0][0]
# ==================================================================================================
# Total params: 102,400
# Trainable params: 102,400
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# Concatenate wont work. You need small concatenate for functional model
#
# https://datascience.stackexchange.com/questions/55050/what-is-the-difference-between-concatenate-and-concatenate-layers-in-keras

# %%
from keras import models
from keras import layers
from keras.utils import plot_model

inp = layers.Input(shape=(5,))

# Branch 1
x = layers.Dense(100, name='material')(inp)
x = layers.Dense(100)(x)
out_1 = layers.Dense(100)(x)

# Branch 2
x1 = layers.Dense(50)(inp)
x1 = layers.Dense(50)(x1)
out_2 = layers.Dense(50)(x1)

merged = layers.concatenate([out_1, out_2])

# func
model = models.Model(inputs=inp, outputs=merged)

model.summary()
plot_model(model, show_shapes=True, show_names=True)
# Out:
# Model: "model_4"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_4 (InputLayer)            (None, 5)            0
# __________________________________________________________________________________________________
# dense_19 (Dense)                (None, 100)          600         input_4[0][0]
# __________________________________________________________________________________________________
# dense_22 (Dense)                (None, 50)           300         input_4[0][0]
# __________________________________________________________________________________________________
# dense_20 (Dense)                (None, 100)          10100       dense_19[0][0]
# __________________________________________________________________________________________________
# dense_23 (Dense)                (None, 50)           2550        dense_22[0][0]
# __________________________________________________________________________________________________
# dense_21 (Dense)                (None, 100)          10100       dense_20[0][0]
# __________________________________________________________________________________________________
# dense_24 (Dense)                (None, 50)           2550        dense_23[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 150)          0           dense_21[0][0]
#                                                                  dense_24[0][0]
# ==================================================================================================
# Total params: 26,200
# Trainable params: 26,200
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
from keras import models
from keras import layers
from keras.utils import plot_model

inp = layers.Input(shape=(150,150,3))

# Branch 1
x = layers.Conv2D(32, (3,3))(inp)
x = layers.Conv2D(32, (3,3))(x)
out_1 = layers.Conv2D(32, (3,3))(x)

# Branch 2
x1 = layers.Conv2D(64, (3,3))(inp)
x1 = layers.Conv2D(32, (3,3))(x1)
out_2 = layers.Conv2D(32, (3,3))(x1)

merged = layers.concatenate([out_1, out_2])

# func
model = models.Model(inputs=inp, outputs=merged)

model.summary()
plot_model(model, show_shapes=True)
# Out:
# Model: "model_5"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_5 (InputLayer)            (None, 150, 150, 3)  0
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 148, 148, 32) 896         input_5[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 148, 148, 64) 1792        input_5[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 146, 146, 32) 9248        conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 146, 146, 32) 18464       conv2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 144, 144, 32) 9248        conv2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 144, 144, 32) 9248        conv2d_5[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 144, 144, 64) 0           conv2d_3[0][0]
#                                                                  conv2d_6[0][0]
# ==================================================================================================
# Total params: 48,896
# Trainable params: 48,896
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# # Example
# Demand prediction

# %% [markdown]
# Sequential

# %%
model = models.Sequential()
model.add(layers.Dense(3, input_shape=(4,), name='hidden_features_detectors'))
model.add(layers.Dense(1, name='demand'))
print(model.summary())
plot_model(model, show_layer_names=True, show_shapes=True)
# Out:
# Model: "sequential_13"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# hidden_features_detectors (D (None, 3)                 15
# _________________________________________________________________
# demand (Dense)               (None, 1)                 4
# =================================================================
# Total params: 19
# Trainable params: 19
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# Embedding of Material

# %%
model = models.Sequential()
# input_dim = number of category levels
# output_dim = embedding dimension/size
model.add(layers.Embedding(input_dim=4, output_dim=3, name='material_embedding'))
model.add(layers.Reshape((3,)))
model.add(layers.Dense(1, name='demand'))
print(model.summary())
plot_model(model, show_layer_names=True, show_shapes=True)
# Out:
# Model: "sequential_14"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# material_embedding (Embeddin (None, None, 3)           12
# _________________________________________________________________
# reshape_17 (Reshape)         (None, 3)                 0
# _________________________________________________________________
# demand (Dense)               (None, 1)                 4
# =================================================================
# Total params: 16
# Trainable params: 16
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# Now let's fuse all features.
#
# You will notice that we cannot do it with Sequential model. Since we have two inputs now:
# - Material
# - Rest of features (numerical)
#
# We must use the functional model

# %%
material = layers.Input(shape=(1,), name='material')
material_emb = layers.Embedding(4, 3, name='material_embedding')(material)
print(material_emb.shape)
material_emb = layers.Reshape((3,))(material_emb)
print(material_emb.shape)
numericals = layers.Input(shape=(3,), name='numericals')
print(numericals.shape)
merged = layers.concatenate([material_emb, numericals], axis=-1)
print(merged.shape)
demand = layers.Dense(1, name='demand')(merged)
model = models.Model([material, numericals], demand)
print(model.summary())
plot_model(model, show_layer_names=True, show_shapes=True)
# Out:
# (None, 1, 3)
# (None, 3)
# (None, 3)
# (None, 6)
# Model: "model_10"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# material (InputLayer)           (None, 1)            0
# __________________________________________________________________________________________________
# material_embedding (Embedding)  (None, 1, 3)         12          material[0][0]
# __________________________________________________________________________________________________
# reshape_13 (Reshape)            (None, 3)            0           material_embedding[0][0]
# __________________________________________________________________________________________________
# numericals (InputLayer)         (None, 3)            0
# __________________________________________________________________________________________________
# concatenate_20 (Concatenate)    (None, 6)            0           reshape_13[0][0]
#                                                                  numericals[0][0]
# __________________________________________________________________________________________________
# demand (Dense)                  (None, 1)            7           concatenate_20[0][0]
# ==================================================================================================
# Total params: 19
# Trainable params: 19
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %% [markdown]
# Material feature first

# %%
material = layers.Input(shape=(1,), name='material')
material_emb = layers.Embedding(4, 3, name='material_embedding')(material)
material_emb = layers.Reshape((3,))(material_emb)
material_feature = layers.Dense(1, name='material_feature')(material_emb)

numericals = layers.Input(shape=(3,), name='numericals')

merged = layers.concatenate([material_feature, numericals], axis=-1)

demand = layers.Dense(1, name='demand')(merged)
model = models.Model([material, numericals], demand)
print(model.summary())
plot_model(model, show_layer_names=True, show_shapes=True)
# Out:
# Model: "model_14"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# material (InputLayer)           (None, 1)            0
# __________________________________________________________________________________________________
# material_embedding (Embedding)  (None, 1, 3)         12          material[0][0]
# __________________________________________________________________________________________________
# reshape_18 (Reshape)            (None, 3)            0           material_embedding[0][0]
# __________________________________________________________________________________________________
# material_feature (Dense)        (None, 1)            4           reshape_18[0][0]
# __________________________________________________________________________________________________
# numericals (InputLayer)         (None, 3)            0
# __________________________________________________________________________________________________
# concatenate_24 (Concatenate)    (None, 4)            0           material_feature[0][0]
#                                                                  numericals[0][0]
# __________________________________________________________________________________________________
# demand (Dense)                  (None, 1)            5           concatenate_24[0][0]
# ==================================================================================================
# Total params: 21
# Trainable params: 21
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %% [markdown]
# Numericals Embedding

# %%
material = layers.Input(shape=(1,), name='material')
material_emb = layers.Embedding(4, 3, name='material_embedding')(material)

material_emb = layers.Reshape((3,))(material_emb)
numericals = layers.Input(shape=(3,), name='numericals')
numericals_emb = layers.Dense(9, name='numerical_embedding')(numericals)
merged = layers.concatenate([material_emb, numericals_emb], axis=-1)

demand = layers.Dense(1, name='demand')(merged)
model = models.Model([material, numericals], demand)
print(model.summary())
plot_model(model, show_layer_names=True, show_shapes=True)
# Out:
# Model: "model_11"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# material (InputLayer)           (None, 1)            0
# __________________________________________________________________________________________________
# material_embedding (Embedding)  (None, 1, 3)         12          material[0][0]
# __________________________________________________________________________________________________
# numericals (InputLayer)         (None, 3)            0
# __________________________________________________________________________________________________
# reshape_14 (Reshape)            (None, 3)            0           material_embedding[0][0]
# __________________________________________________________________________________________________
# numerical_embedding (Dense)     (None, 9)            36          numericals[0][0]
# __________________________________________________________________________________________________
# concatenate_21 (Concatenate)    (None, 12)           0           reshape_14[0][0]
#                                                                  numerical_embedding[0][0]
# __________________________________________________________________________________________________
# demand (Dense)                  (None, 1)            13          concatenate_21[0][0]
# ==================================================================================================
# Total params: 61
# Trainable params: 61
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %% [markdown]
# Learnable sum

# %%
material = layers.Input(shape=(1,), name='material')
material_emb = layers.Embedding(4, 3, name='material_embedding')(material)

material_emb = layers.Reshape((3,))(material_emb)
numericals = layers.Input(shape=(3,), name='numericals')
numericals_emb = layers.Dense(9, name='numerical_embedding')(numericals)
merged = layers.concatenate([material_emb, numericals_emb], axis=-1)
merged = layers.Dense(2, name='learnable_weighted_sum')(merged)
demand = layers.Dense(1, name='demand')(merged)
model = models.Model([material, numericals], demand)
print(model.summary())
plot_model(model, show_layer_names=True, show_shapes=True)
# Out:
# Model: "model_15"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# material (InputLayer)           (None, 1)            0
# __________________________________________________________________________________________________
# material_embedding (Embedding)  (None, 1, 3)         12          material[0][0]
# __________________________________________________________________________________________________
# numericals (InputLayer)         (None, 3)            0
# __________________________________________________________________________________________________
# reshape_21 (Reshape)            (None, 3)            0           material_embedding[0][0]
# __________________________________________________________________________________________________
# numerical_embedding (Dense)     (None, 9)            36          numericals[0][0]
# __________________________________________________________________________________________________
# concatenate_25 (Concatenate)    (None, 12)           0           reshape_21[0][0]
#                                                                  numerical_embedding[0][0]
# __________________________________________________________________________________________________
# learnable_weighted_sum (Dense)  (None, 2)            26          concatenate_25[0][0]
# __________________________________________________________________________________________________
# demand (Dense)                  (None, 1)            3           learnable_weighted_sum[0][0]
# ==================================================================================================
# Total params: 77
# Trainable params: 77
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %% [markdown]
# Let's have separate embedding per each numerical
#
# The following is exactly equivalent to the the above model, just separating every 1 of the 3 numericals alone.

# %%
material = layers.Input(shape=(1,), name='material')
material_emb = layers.Embedding(4, 3, name='material_embedding')(material)
material_emb = layers.Reshape((3,))(material_emb)

price = layers.Input(shape=(1,), name='price')
price_emb = layers.Dense(3, name='price_embedding')(price)

shipping_cost = layers.Input(shape=(1,), name='shipping_cost')
shipping_cost_emb = layers.Dense(3, name='shipping_cost_embedding')(shipping_cost)

marketing = layers.Input(shape=(1,), name='marketing')
marketing_emb = layers.Dense(3, name='marketing_embedding')(marketing)

merged = layers.concatenate([material_emb, price_emb, shipping_cost_emb, marketing_emb], axis=-1)

demand = layers.Dense(1, name='demand')(merged)
model = models.Model([material, price, shipping_cost, marketing], demand)
print(model.summary())
plot_model(model, show_layer_names=True, show_shapes=True)
# Out:
# Model: "model_12"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# material (InputLayer)           (None, 1)            0
# __________________________________________________________________________________________________
# material_embedding (Embedding)  (None, 1, 3)         12          material[0][0]
# __________________________________________________________________________________________________
# price (InputLayer)              (None, 1)            0
# __________________________________________________________________________________________________
# shipping_cost (InputLayer)      (None, 1)            0
# __________________________________________________________________________________________________
# marketing (InputLayer)          (None, 1)            0
# __________________________________________________________________________________________________
# reshape_15 (Reshape)            (None, 3)            0           material_embedding[0][0]
# __________________________________________________________________________________________________
# price_embedding (Dense)         (None, 3)            6           price[0][0]
# __________________________________________________________________________________________________
# shipping_cost_embedding (Dense) (None, 3)            6           shipping_cost[0][0]
# __________________________________________________________________________________________________
# marketing_embedding (Dense)     (None, 3)            6           marketing[0][0]
# __________________________________________________________________________________________________
# concatenate_22 (Concatenate)    (None, 12)           0           reshape_15[0][0]
#                                                                  price_embedding[0][0]
#                                                                  shipping_cost_embedding[0][0]
#                                                                  marketing_embedding[0][0]
# __________________________________________________________________________________________________
# demand (Dense)                  (None, 1)            13          concatenate_22[0][0]
# ==================================================================================================
# Total params: 43
# Trainable params: 43
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %% [markdown]
# Auxilary task

# %%
numericals = layers.Input(shape=(100,), name='material')
embs=[]
for i in range(100):
  numercal_var = layers.Lambda(lambda x:x[:,i])
  embs[i] = layers.Embedding(num_ems, emb_sz)(numercal_var)

material = layers.Input(shape=(1,), name='material')
material_emb = layers.Embedding(4, 3, name='material_embedding')(material)
material_emb = layers.Reshape((3,))(material_emb)

price = layers.Input(shape=(1,), name='price')
price_emb = layers.Dense(3, name='price_embedding')(price)

shipping_cost = layers.Input(shape=(1,), name='shipping_cost')
shipping_cost_emb = layers.Dense(3, name='shipping_cost_embedding')(shipping_cost)

marketing = layers.Input(shape=(1,), name='marketing')
marketing_emb = layers.Dense(3, name='marketing_embedding')(marketing)

merged = layers.concatenate([material_emb, price_emb, shipping_cost_emb, marketing_emb], axis=-1)
merged = layers.Dense(3, name='learnable_weighted_sum')(merged)
demand = layers.Dense(1, name='demand')(merged)
quality = layers.Lambda(lambda x:x[:,-1], name='quality')(merged)
model = models.Model([material, price, shipping_cost, marketing], [demand, quality])
print(model.summary())
plot_model(model, show_layer_names=True, show_shapes=True)
# Out:
# Model: "model_18"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# material (InputLayer)           (None, 1)            0
# __________________________________________________________________________________________________
# material_embedding (Embedding)  (None, 1, 3)         12          material[0][0]
# __________________________________________________________________________________________________
# price (InputLayer)              (None, 1)            0
# __________________________________________________________________________________________________
# shipping_cost (InputLayer)      (None, 1)            0
# __________________________________________________________________________________________________
# marketing (InputLayer)          (None, 1)            0
# __________________________________________________________________________________________________
# reshape_26 (Reshape)            (None, 3)            0           material_embedding[0][0]
# __________________________________________________________________________________________________
# price_embedding (Dense)         (None, 3)            6           price[0][0]
# __________________________________________________________________________________________________
# shipping_cost_embedding (Dense) (None, 3)            6           shipping_cost[0][0]
# __________________________________________________________________________________________________
# marketing_embedding (Dense)     (None, 3)            6           marketing[0][0]
# __________________________________________________________________________________________________
# concatenate_30 (Concatenate)    (None, 12)           0           reshape_26[0][0]
#                                                                  price_embedding[0][0]
#                                                                  shipping_cost_embedding[0][0]
#                                                                  marketing_embedding[0][0]
# __________________________________________________________________________________________________
# learnable_weighted_sum (Dense)  (None, 3)            39          concatenate_30[0][0]
# __________________________________________________________________________________________________
# demand (Dense)                  (None, 1)            4           learnable_weighted_sum[0][0]
# __________________________________________________________________________________________________
# quality (Lambda)                (None,)              0           learnable_weighted_sum[0][0]
# ==================================================================================================
# Total params: 73
# Trainable params: 73
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %% [markdown]
# MTL

# %%
material = layers.Input(shape=(1,), name='material')
material_emb = layers.Embedding(4, 3, name='material_embedding')(material)
material_emb = layers.Reshape((3,))(material_emb)

price = layers.Input(shape=(1,), name='price')
price_emb = layers.Dense(3, name='price_embedding')(price)

shipping_cost = layers.Input(shape=(1,), name='shipping_cost')
shipping_cost_emb = layers.Dense(3, name='shipping_cost_embedding')(shipping_cost)

marketing = layers.Input(shape=(1,), name='marketing')
marketing_emb = layers.Dense(3, name='marketing_embedding')(marketing)

merged = layers.concatenate([material_emb, price_emb, shipping_cost_emb, marketing_emb], axis=-1)
merged = layers.Dense(3, name='learnable_weighted_sum')(merged)
demand = layers.Dense(1, name='demand')(merged)
quality = layers.Dense(1, name='quality')(merged)
model = models.Model([material, price, shipping_cost, marketing], [demand, quality])
print(model.summary())
plot_model(model, show_layer_names=True, show_shapes=True)
# Out:
# Model: "model_19"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# material (InputLayer)           (None, 1)            0
# __________________________________________________________________________________________________
# material_embedding (Embedding)  (None, 1, 3)         12          material[0][0]
# __________________________________________________________________________________________________
# price (InputLayer)              (None, 1)            0
# __________________________________________________________________________________________________
# shipping_cost (InputLayer)      (None, 1)            0
# __________________________________________________________________________________________________
# marketing (InputLayer)          (None, 1)            0
# __________________________________________________________________________________________________
# reshape_27 (Reshape)            (None, 3)            0           material_embedding[0][0]
# __________________________________________________________________________________________________
# price_embedding (Dense)         (None, 3)            6           price[0][0]
# __________________________________________________________________________________________________
# shipping_cost_embedding (Dense) (None, 3)            6           shipping_cost[0][0]
# __________________________________________________________________________________________________
# marketing_embedding (Dense)     (None, 3)            6           marketing[0][0]
# __________________________________________________________________________________________________
# concatenate_31 (Concatenate)    (None, 12)           0           reshape_27[0][0]
#                                                                  price_embedding[0][0]
#                                                                  shipping_cost_embedding[0][0]
#                                                                  marketing_embedding[0][0]
# __________________________________________________________________________________________________
# learnable_weighted_sum (Dense)  (None, 3)            39          concatenate_31[0][0]
# __________________________________________________________________________________________________
# demand (Dense)                  (None, 1)            4           learnable_weighted_sum[0][0]
# __________________________________________________________________________________________________
# quality (Dense)                 (None, 1)            4           learnable_weighted_sum[0][0]
# ==================================================================================================
# Total params: 77
# Trainable params: 77
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %% [markdown]
# Multi-modalities

# %%
material = layers.Input(shape=(1,), name='material')
material_emb = layers.Embedding(4, 3, name='material_embedding')(material)
material_emb = layers.Reshape((3,))(material_emb)

price = layers.Input(shape=(1,), name='price')
price_emb = layers.Dense(3, name='price_embedding')(price)

shipping_cost = layers.Input(shape=(1,), name='shipping_cost')
shipping_cost_emb = layers.Dense(3, name='shipping_cost_embedding')(shipping_cost)

marketing = layers.Input(shape=(1,), name='marketing')
marketing_emb = layers.Dense(3, name='marketing_embedding')(marketing)

image = layers.Input(shape=(224,224,3), name='image')
image_features = layers.Conv2D(64, 3)(image)
image_features = layers.Flatten()(image_features)

text = layers.Input(shape=(10,), name='text')
text_features = layers.Embedding(50, 3)(text)
text_features = layers.LSTM(10)(text_features)


merged = layers.concatenate([material_emb, price_emb, shipping_cost_emb, marketing_emb, image_features, text_features], axis=-1)
merged = layers.Dense(3, name='learnable_weighted_sum')(merged)
demand = layers.Dense(1, name='demand')(merged)
quality = layers.Dense(1, name='quality')(merged)
model = models.Model([image, text, material, price, shipping_cost, marketing], [demand, quality])
print(model.summary())
plot_model(model, show_layer_names=True, show_shapes=True)
# Out:
# Model: "model_22"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# material (InputLayer)           (None, 1)            0
# __________________________________________________________________________________________________
# image (InputLayer)              (None, 224, 224, 3)  0
# __________________________________________________________________________________________________
# text (InputLayer)               (None, 10)           0
# __________________________________________________________________________________________________
# material_embedding (Embedding)  (None, 1, 3)         12          material[0][0]
# __________________________________________________________________________________________________
# price (InputLayer)              (None, 1)            0
# __________________________________________________________________________________________________
# shipping_cost (InputLayer)      (None, 1)            0
# __________________________________________________________________________________________________
# marketing (InputLayer)          (None, 1)            0
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 222, 222, 64) 1792        image[0][0]
# __________________________________________________________________________________________________
# embedding_3 (Embedding)         (None, 10, 3)        150         text[0][0]
# __________________________________________________________________________________________________
# reshape_32 (Reshape)            (None, 3)            0           material_embedding[0][0]
# __________________________________________________________________________________________________
# price_embedding (Dense)         (None, 3)            6           price[0][0]
# __________________________________________________________________________________________________
# shipping_cost_embedding (Dense) (None, 3)            6           shipping_cost[0][0]
# __________________________________________________________________________________________________
# marketing_embedding (Dense)     (None, 3)            6           marketing[0][0]
# __________________________________________________________________________________________________
# flatten_4 (Flatten)             (None, 3154176)      0           conv2d_11[0][0]
# __________________________________________________________________________________________________
# lstm_3 (LSTM)                   (None, 10)           560         embedding_3[0][0]
# __________________________________________________________________________________________________
# concatenate_34 (Concatenate)    (None, 3154198)      0           reshape_32[0][0]
#                                                                  price_embedding[0][0]
#                                                                  shipping_cost_embedding[0][0]
#                                                                  marketing_embedding[0][0]
#                                                                  flatten_4[0][0]
#                                                                  lstm_3[0][0]
# __________________________________________________________________________________________________
# learnable_weighted_sum (Dense)  (None, 3)            9462597     concatenate_34[0][0]
# __________________________________________________________________________________________________
# demand (Dense)                  (None, 1)            4           learnable_weighted_sum[0][0]
# __________________________________________________________________________________________________
# quality (Dense)                 (None, 1)            4           learnable_weighted_sum[0][0]
# ==================================================================================================
# Total params: 9,465,137
# Trainable params: 9,465,137
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %% [markdown]
# + Video

# %%
material = layers.Input(shape=(1,), name='material')
material_emb = layers.Embedding(4, 3, name='material_embedding')(material)
material_emb = layers.Reshape((3,))(material_emb)

price = layers.Input(shape=(1,), name='price')
price_emb = layers.Dense(3, name='price_embedding')(price)

shipping_cost = layers.Input(shape=(1,), name='shipping_cost')
shipping_cost_emb = layers.Dense(3, name='shipping_cost_embedding')(shipping_cost)

marketing = layers.Input(shape=(1,), name='marketing')
marketing_emb = layers.Dense(3, name='marketing_embedding')(marketing)

image = layers.Input(shape=(224,224,3), name='image')
image_features = layers.Conv2D(64, 3)(image)
image_features = layers.Flatten()(image_features)

n_steps = 10
video = layers.Input(shape=(n_steps,224,224,3), name='video')
video_features = layers.TimeDistributed(layers.Conv2D(64, 3))(video)
video_features = layers.TimeDistributed(layers.Flatten())(video_features)
print(video_features.shape)
video_features = layers.LSTM(10)(video_features)

text = layers.Input(shape=(10,), name='text')
text_features = layers.Embedding(50, 3)(text)
text_features = layers.LSTM(10)(text_features)

merged = layers.concatenate([material_emb, price_emb, shipping_cost_emb, marketing_emb, image_features, text_features, video_features], axis=-1)
merged = layers.Dense(3, name='learnable_weighted_sum')(merged)
demand = layers.Dense(1, name='demand')(merged)
quality = layers.Dense(1, name='quality')(merged)
model = models.Model([video, image, text, material, price, shipping_cost, marketing], [demand, quality])
print(model.summary())
plot_model(model, show_layer_names=True, show_shapes=True)
# Out:
# (None, 10, 3154176)
# Model: "model_23"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# video (InputLayer)              (None, 10, 224, 224, 0
# __________________________________________________________________________________________________
# material (InputLayer)           (None, 1)            0
# __________________________________________________________________________________________________
# image (InputLayer)              (None, 224, 224, 3)  0
# __________________________________________________________________________________________________
# text (InputLayer)               (None, 10)           0
# __________________________________________________________________________________________________
# time_distributed_3 (TimeDistrib (None, 10, 222, 222, 1792        video[0][0]
# __________________________________________________________________________________________________
# material_embedding (Embedding)  (None, 1, 3)         12          material[0][0]
# __________________________________________________________________________________________________
# price (InputLayer)              (None, 1)            0
# __________________________________________________________________________________________________
# shipping_cost (InputLayer)      (None, 1)            0
# __________________________________________________________________________________________________
# marketing (InputLayer)          (None, 1)            0
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 222, 222, 64) 1792        image[0][0]
# __________________________________________________________________________________________________
# embedding_4 (Embedding)         (None, 10, 3)        150         text[0][0]
# __________________________________________________________________________________________________
# time_distributed_4 (TimeDistrib (None, 10, 3154176)  0           time_distributed_3[0][0]
# __________________________________________________________________________________________________
# reshape_35 (Reshape)            (None, 3)            0           material_embedding[0][0]
# __________________________________________________________________________________________________
# price_embedding (Dense)         (None, 3)            6           price[0][0]
# __________________________________________________________________________________________________
# shipping_cost_embedding (Dense) (None, 3)            6           shipping_cost[0][0]
# __________________________________________________________________________________________________
# marketing_embedding (Dense)     (None, 3)            6           marketing[0][0]
# __________________________________________________________________________________________________
# flatten_9 (Flatten)             (None, 3154176)      0           conv2d_16[0][0]
# __________________________________________________________________________________________________
# lstm_7 (LSTM)                   (None, 10)           560         embedding_4[0][0]
# __________________________________________________________________________________________________
# lstm_6 (LSTM)                   (None, 10)           126167480   time_distributed_4[0][0]
# __________________________________________________________________________________________________
# concatenate_35 (Concatenate)    (None, 3154208)      0           reshape_35[0][0]
#                                                                  price_embedding[0][0]
#                                                                  shipping_cost_embedding[0][0]
#                                                                  marketing_embedding[0][0]
#                                                                  flatten_9[0][0]
#                                                                  lstm_7[0][0]
#                                                                  lstm_6[0][0]
# __________________________________________________________________________________________________
# learnable_weighted_sum (Dense)  (None, 3)            9462627     concatenate_35[0][0]
# __________________________________________________________________________________________________
# demand (Dense)                  (None, 1)            4           learnable_weighted_sum[0][0]
# __________________________________________________________________________________________________
# quality (Dense)                 (None, 1)            4           learnable_weighted_sum[0][0]
# ==================================================================================================
# Total params: 135,634,439
# Trainable params: 135,634,439
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None
